# %% [markdown]
# # Task 2: Feb Internship Logic Building Task

# %% [markdown]
# ### Python Programming Practice Problems

# %% [markdown]
# # Problem 1: Unique Words in a Sentence

# %%
# given
message = "python is easy and python is powerful"

# spliting words
words = message.split()
# remove duplicates
uq_words = set(words)

print("Unique words count:", len(uq_words))
print("Unique words:", uq_words)
# Out:
# Unique words count: 5
# Unique words: {'python', 'is', 'and', 'powerful', 'easy'}

# %% [markdown]
# # Real-Time Applications
# - Text analytics
# - Natural Language Processing (NLP) preprocessing
# - Search engine indexing
# - Chat analysis systems

# %% [markdown]
# # Problem 2: Highest Salary from Employee Data

# %%
# given
employees = {
    "Ravi": 75000,
    "Anita": 68000,
    "Kiran": 72000
}

high_empl= max(employees, key=employees.get) # 'get' is used to get the value of a key
high_sal = employees[high_empl]

print("Highest Salary:", high_empl, ":", high_sal)
# Out:
# Highest Salary: Ravi : 75000

# %% [markdown]
# # Real-Time Applications
# - HR management systems
# - Payroll analysis

# %% [markdown]
# # Problem 3: Find Maximum and Minimum Values

# %%
# given
numbers = [45, 22, 89, 10, 66]

# initialize
max_value = numbers[0]
min_value = numbers[0]

for n in numbers:
    if n > max_value:
        max_value = n
    if n < min_value:
        min_value = n

print("List:", numbers)
print("Max:", max_value)
print("Min:", min_value)
# Out:
# List: [45, 22, 89, 10, 66]
# Max: 89
# Min: 10

# %% [markdown]
# # Real-Time Applications
# - Sales data analysis
# - Temperature monitoring systems
# - Performance metric evaluation

# %% [markdown]
# # Problem 4: Count Products Above a Price Threshold

# %%
# given
prices = [450, 1200, 899, 1500, 300]
count = 0

for n in prices:
    if n > 1000:
        count += 1

print("Products above 1000:", count)
# Out:
# Products above 1000: 2

# %% [markdown]
# #  Real-Time Applications
# - E-commerce product filtering
# - Budget analysis

# %% [markdown]
# # Problem 5: Calculate Attendance Percentage

# %%
# given
attendance = ["P", "P", "A", "P", "P"]

# 'count' is used to count the number of letters
present_ct = attendance.count("P")

total = len(attendance)
attendance_perct = (present_ct / total) * 100

print("Attendance Percentage:", attendance_perct)
# Out:
# Attendance Percentage: 80.0

# %% [markdown]
# # Real-Time Applications
# - Internship tracking systems
# - HR attendance management systems

# %% [markdown]
# # Problem 6: Remove Duplicate Phone Numbers

# %%
phone_numbers = [9876543210, 9123456789, 9876543210]

# remove duplicates
uniq_no = set(phone_numbers)

print("Unique phone numbers:", uniq_no)
# Out:
# Unique phone numbers: {9876543210, 9123456789}

# %% [markdown]
# # Real-Time Applications
# - Contact management applications
# - Customer Relationship Management (CRM) systems
# - Marketing databases

# %% [markdown]
# # Problem 7: Count Character Frequency

# %%
text = "alphabet"

# dictionary
char_frq = {}

#loop
for n in text:
    if n in char_frq:
        char_frq[n] += 1
    else:
        char_frq[n] = 1

print(char_frq)
# Out:
# {'a': 2, 'l': 1, 'p': 1, 'h': 1, 'b': 1, 'e': 1, 't': 1}

# %% [markdown]
# # Real-Time Applications
# - Text analysis
# - Password strength validation

# %% [markdown]
# # Problem 8: Convert List to Tuple

# %%
# given
numbers = [10, 20, 30]

# convert list to tuple
cov_tuple = tuple(numbers)

print("Tuple:",cov_tuple)
# Out:
# Tuple: (10, 20, 30)

# %% [markdown]
# # Real-Time Applications
# - Making data read-only
# - Configuration settings storage

# %% [markdown]
# # Problem 9: Check if a Key Exists in a Dictionary

# %%
# given
department = {
    "Employee": "Sam",
    "Salary": 85000,
    "Department": "IT"
}
# loops
if "Employee" in department:
    print("Employee exists")
else:
    print("Employee does not exist")
# Out:
# Employee exists

# %% [markdown]
# # Real-Time Applications
# - User validation systems
# - Configuration verification

# %% [markdown]
# # Problem 10: Calculate Average Marks

# %%
marks = [80, 70, 65, 75]

total = sum(marks) # sum
count = len(marks) # length

avg = total/count # average

print("Average Marks:",avg)
# Out:
# Average Marks: 72.5

# %% [markdown]
# # Real-Time Applications
# - Student performance evaluation
# - Result processing systems
